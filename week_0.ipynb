# %% [markdown]
# <a href="https://colab.research.google.com/github/Aishaamalik/Data-Analysis-Intern/blob/main/week_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introduction to Python for Data Analysis

# %% [markdown]
# ## 📘 Introduction
#
# This tutorial introduces **Python for data analysis**, ideal for those transitioning from **R, Excel, or SAS**. Unlike R, which is specialized for statistical tasks, **Python is a general-purpose language** that has become powerful for data science thanks to libraries like `pandas`, `numpy`, and `scikit-learn`. With its **clean syntax**, **broad ecosystem**, and **strong community**, Python offers flexibility and is widely used for **data manipulation**, **analysis**, and **machine learning**.
#
# We’ll use **Google Colab** — a cloud-based, Jupyter-like environment — for hands-on coding without the need for local setup.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #1 Importing Data with Pandas in Google Colab
#
# This notebook will guide you through loading data, exploring it, and converting data types using Pandas.
#
# ---
#
# ## 1.1. Loading the Pandas Library
#
# Pandas is a powerful Python library for working with tabular data (like Excel spreadsheets or database tables).

# %%
import pandas as pd

# %% [markdown]
# ##1.2. Creating a DataFrame object

# %%
# Upload files from your local machine in Colab
from google.colab import files

uploaded = files.upload()
# After uploading, you can read the CSV by its filename

bank = pd.read_csv('Bank.csv')
bank.head()  # Show first 5 rows
# Out:
#      <input type="file" id="files-b65abbfb-58c5-4bc3-a323-8598f9b54752" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b65abbfb-58c5-4bc3-a323-8598f9b54752">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ##1.3. Creating a DataFrame object from an Excel file

# %%
# Upload files from your local machine in Colab
from google.colab import files

uploaded = files.upload()
# After uploading, you can read the CSV by its filename
# Make sure you upload the Excel file first (same as CSV)
bankxl = pd.read_excel('Bank1.xlsx')
bankxl.head()
# Out:
#      <input type="file" id="files-678a6667-5bae-4d9d-b2cc-6974d0a49b1e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-678a6667-5bae-4d9d-b2cc-6974d0a49b1e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # 1.4 Confirming DataFrame Properties
#
# As noted previously, objects in Python expose useful **properties** and **methods**. For example, we can confirm the size of the `bank` DataFrame with the `shape` property, which gives us the number of rows and columns:

# %%
bank.shape
# Out:
# (100, 9)

# %% [markdown]
# ###The describe() Method
# The describe() method generates summary statistics for numerical columns:

# %%
bank.describe()
# Out:
#          Employee     EducLev    JobGrade      YrHired       YrBorn  \
# count  100.000000  100.000000  100.000000   100.000000   100.000000
# mean    50.500000    4.530000    2.970000  1992.910000  1959.230000
# std     29.011492    1.473366    1.540399    15.129805    20.599527
# min      1.000000    2.000000    1.000000  1960.000000  1903.000000
# 25%     25.750000    3.000000    2.000000  1982.000000  1948.500000
# 50%     50.500000    5.000000    3.000000  1993.500000  1962.000000
# 75%     75.250000    6.000000    4.000000  2006.250000  1972.500000
# max    100.000000    7.000000    6.000000  2018.000000  1997.000000
#
#          YrsPrior      Salary
# count  100.000000  100.000000
# mean     4.220000   45.846000
# std      2.798196    4.827058
# min      0.000000   35.600000
# 25%      2.000000   42.550000
# 50%      4.000000   45.400000
# 75%      6.000000   49.100000
# max      9.000000   57.000000

# %% [markdown]
# Sample output includes count, mean, standard deviation, min, max, and quartiles:

# %% [markdown]
# ###The info() Method
# The info() method provides a concise summary of the DataFrame structure:

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Employee  100 non-null    int64
#  1   EducLev   100 non-null    int64
#  2   JobGrade  100 non-null    int64
#  3   YrHired   100 non-null    int64
#  4   YrBorn    100 non-null    int64
#  5   Gender    100 non-null    object
#  6   YrsPrior  100 non-null    int64
#  7   PCJob     100 non-null    object
#  8   Salary    100 non-null    float64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 7.2+ KB

# %% [markdown]
# Here we see:
#
# Integer columns: Employee, EducLev, JobGrade, YrHired, YrBorn, YrsPrior
#
# Floating point column: Salary
#
# Object (string) columns: Gender, PCJob

# %% [markdown]
# ###Properties vs Methods
#
# *   Properties like shape give direct information — accessed without parentheses.
# *   Methods like describe() and info() perform operations and are called with parentheses.

# %%
print(bank.shape)
print(bank.describe())
print(bank.info())
# Out:
# (100, 9)
#          Employee     EducLev    JobGrade      YrHired       YrBorn  \
# count  100.000000  100.000000  100.000000   100.000000   100.000000
# mean    50.500000    4.530000    2.970000  1992.910000  1959.230000
# std     29.011492    1.473366    1.540399    15.129805    20.599527
# min      1.000000    2.000000    1.000000  1960.000000  1903.000000
# 25%     25.750000    3.000000    2.000000  1982.000000  1948.500000
# 50%     50.500000    5.000000    3.000000  1993.500000  1962.000000
# 75%     75.250000    6.000000    4.000000  2006.250000  1972.500000
# max    100.000000    7.000000    6.000000  2018.000000  1997.000000
#
#          YrsPrior      Salary
# count  100.000000  100.000000
# mean     4.220000   45.846000
# std      2.798196    4.827058
# min      0.000000   35.600000
# 25%      2.000000   42.550000
# 50%      4.000000   45.400000
# 75%      6.000000   49.100000
# max      9.000000   57.000000
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# # 1.5 Converting Strings to Categories
#
# In data analysis, it's important to distinguish between general strings (text data) and **categorical data** that represent a limited set of possible values.
#
# ### What is a Category?
#
# - In **R**, categorical data are called **factors**. For example, a factor like `Color` might take only a few values: `"red"`, `"green"`, `"blue"`.
# - In **Pandas/Python**, these are called **categories** instead of factors — a more intuitive term.
#
# ---
#
# ### Why convert strings to categories?
#
# - **Categories** are more memory efficient and can speed up operations.
# - They explicitly represent data with a limited set of values.
# - Useful for statistical analysis, plotting, and machine learning.
#
# ---
#
# ### How to convert strings to categories in Pandas
#
# Suppose our DataFrame `bank` has two string (object) columns: `Gender` and `PCJob`.
#
# There are two ways to reference columns in Pandas:
#
# - **Square bracket notation** (more flexible):

# %%
bank['Gender']
# Out:
# 0     Female
# 1     Female
# 2       Male
# 3       Male
# 4     Female
#        ...
# 95      Male
# 96      Male
# 97      Male
# 98      Male
# 99    Female
# Name: Gender, Length: 100, dtype: object

# %% [markdown]
# ###Conversion syntax
# To convert a string column to a category, use the .astype('category') method:

# %%
bank['Gender'] = bank['Gender'].astype('category')
bank['PCJob'] = bank['PCJob'].astype('category')

# %% [markdown]
# What happens after conversion?
# If you print the column after conversion:

# %%
print(bank['Gender'].astype('category'))
# Out:
# 0     Female
# 1     Female
# 2       Male
# 3       Male
# 4     Female
#        ...
# 95      Male
# 96      Male
# 97      Male
# 98      Male
# 99    Female
# Name: Gender, Length: 100, dtype: category
# Categories (2, object): ['Female', 'Male']

# %% [markdown]
# This indicates that the Gender column now has 2 categories: "Female" and "Male".

# %% [markdown]
# ###Confirming categories with describe()
# After converting, you can get summary statistics for only the categorical columns by using:

# %%
bank.describe(include='category')
# Out:
#        Gender PCJob
# count     100   100
# unique      2     2
# top      Male    No
# freq       67    90

# %% [markdown]
# *   Categories improve data handling and clarity.
#
#
#
#
#
# *   Use .astype('category') to convert.
#
# *   Use describe(include='category') to analyze categorical columns.

# %%
bank['Gender'] = bank['Gender'].astype('category')
bank['PCJob'] = bank['PCJob'].astype('category')

print(bank.describe(include='category'))
# Out:
#        Gender PCJob
# count     100   100
# unique      2     2
# top      Male    No
# freq       67    90

# %% [markdown]
# # 1.6 Type Conversion Using Programming Constructs
#
# When working with larger datasets, manually converting string columns to categories one by one may not be efficient. Python provides **programmatic constructs** like **lists** and **loops** to help automate repetitive tasks such as type conversion.
#
# ---
#
# ### The Goal
#
# Convert multiple object-type columns (like `Gender`, `PCJob`, etc.) to **category** type in a scalable way using a `for` loop.
#
# ---
#
# ### Step-by-Step Plan
#
# 1. **Create a list** of the column names you want to convert.
# 2. **Loop through** each column in the list.
# 3. **Apply `.astype('category')`** to each column.
# 4. **Assign it back** to the original DataFrame.

# %%
# Step 1: Define a list of columns to convert
categorical_columns = ['Gender', 'PCJob']

# Step 2: Loop and convert each to category
for col in categorical_columns:
    bank[col] = bank[col].astype('category')

# Step 3: Verify the changes
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Employee  100 non-null    int64
#  1   EducLev   100 non-null    int64
#  2   JobGrade  100 non-null    int64
#  3   YrHired   100 non-null    int64
#  4   YrBorn    100 non-null    int64
#  5   Gender    100 non-null    category
#  6   YrsPrior  100 non-null    int64
#  7   PCJob     100 non-null    category
#  8   Salary    100 non-null    float64
# dtypes: category(2), float64(1), int64(6)
# memory usage: 6.0 KB

# %% [markdown]
# This confirms that:
#
#
# *   Gender and PCJob are now category types.
#
#
# *   The approach is more scalable for larger datasets.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 2. Basic Visualization
#  how Python and its graphics libraries can be used to create the two most common types of distributional plots: histograms and boxplots.

# %% [markdown]
# #2.1. Preliminaries

# %%
import pandas as pd

# Load the dataset
bank = pd.read_csv('Data/Bank.csv')

# %% [markdown]
# #2.2 Basic Descriptive Statistics
# Pandas provides convenient methods for computing basic descriptive statistics.
#
# 📈 Mean Salary of Employees

# %%
bank['Salary'].mean()
# Out:
# np.float64(45.846)

# %%
# If you want to convert it to a regular Python float:
float(bank['Salary'].mean())
# Out:
# 45.846

# %% [markdown]
# 💡 Store column in a variable to reduce typing:

# %%
sal = bank['Salary']
sal.min(), sal.mean(), sal.median(), sal.max()
# Out:
# (35.6, np.float64(45.846), 45.4, 57.0)

# %% [markdown]
# 📊 Full Numerical Summary

# %%
bank.describe()
# Out:
#          Employee     EducLev    JobGrade      YrHired       YrBorn  \
# count  100.000000  100.000000  100.000000   100.000000   100.000000
# mean    50.500000    4.530000    2.970000  1992.910000  1959.230000
# std     29.011492    1.473366    1.540399    15.129805    20.599527
# min      1.000000    2.000000    1.000000  1960.000000  1903.000000
# 25%     25.750000    3.000000    2.000000  1982.000000  1948.500000
# 50%     50.500000    5.000000    3.000000  1993.500000  1962.000000
# 75%     75.250000    6.000000    4.000000  2006.250000  1972.500000
# max    100.000000    7.000000    6.000000  2018.000000  1997.000000
#
#          YrsPrior      Salary
# count  100.000000  100.000000
# mean     4.220000   45.846000
# std      2.798196    4.827058
# min      0.000000   35.600000
# 25%      2.000000   42.550000
# 50%      4.000000   45.400000
# 75%      6.000000   49.100000
# max      9.000000   57.000000

# %% [markdown]
# #2.3. Histograms in Seaborn
# Seaborn is a high-level visualization library built on Matplotlib. It makes creating complex plots very simple.
# We’ll use Seaborn to generate histograms (distribution plots) and boxplots.

# %% [markdown]
# #2.4. Loading the Library
# Let’s load Seaborn. The alias sns is a community convention.

# %%
import seaborn as sns

# %% [markdown]
# #2.5. Creating a Histogram
# We use Seaborn's histplot() to create histograms. This function is similar in spirit to R’s ggplot, where the data is passed explicitly and plotting is declarative.

# %% [markdown]
# 🔹 Basic Histogram of Salary

# %%
import seaborn as sns

# Basic histogram
sns.histplot(x=bank['Salary'],color='yellow'  );

# %% [markdown]
# *   The histplot() function returns an AxesSubplot object (which we typically ignore).
# *   By ending the command with a semicolon (;), we suppress the unwanted text output and just display the plot.
# *   Seaborn automatically determines a suitable number of bins.

# %% [markdown]
# 🔹 Histogram with Custom Bins and Kernel Density Estimation (KDE)
# You can control the number of bins and add a KDE (Kernel Density Estimate) line for a smoother approximation of the distribution:

# %%
# Histogram with 10 bins and KDE overlay
sns.histplot(x=bank['Salary'], bins=10, kde=True,color='yellow' );

# %% [markdown]
# 🔹 Advanced Histogram with Probability and Color
#
# This version adds custom styling:

# %%
# Enhanced histogram
sns.histplot(
    x=bank['Salary'],
    bins=10,
    kde=False,
    stat="probability",  # Normalize to probability
    color='yellow'        # Change bar color
);

# %% [markdown]
# #2.6. Creating a Boxplot
# Boxplots give a five-number summary: minimum, Q1, median, Q3, and maximum.
# They also help spot outliers and visualize skewness.
#
# 🔹 Basic Boxplot of Salary

# %%
# Horizontal boxplot
sns.boxplot(x=bank['Salary'], showfliers=True);

# %% [markdown]
# 🔹 Vertical Boxplot with Mean Indicator
#
# Seaborn does not show the mean by default, but we can enable it with showmeans=True.

# %%
# Vertical boxplot with light color and mean shown
sns.boxplot(
    y=bank['Salary'],
    color='yellow',
    showmeans=True
);

# %% [markdown]
# The dots were not showing so I added this

# %%
import matplotlib.pyplot as plt

# Boxplot + jittered stripplot for all points
sns.boxplot(x=bank['Salary'], showfliers=True, color='lightblue');
sns.stripplot(x=bank['Salary'], color='black', alpha=0.5, jitter=True);

plt.title("Salary Distribution with Individual Data Points");

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 3. Filtering Data 📌
#
# Filtering means limiting **rows** and/or **columns**. It’s a central concept in all data analysis — helping us extract subsets of interest for further inspection or modeling.
#
# ---
#
# ## 3.1. Preliminaries 🔧
#
# We begin by importing the necessary library and loading the dataset. This ensures each section is self-contained.

# %%
import pandas as pd
bank = pd.read_csv('Data/Bank.csv')

# %% [markdown]
# #3.2. Boolean Vectors ✅❌
# Filtering in Pandas is built on Boolean vectors — arrays of True or False values.

# %%
# Generate a Boolean vector where Gender is 'Female'
bank['Gender'] == 'Female'
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4      True
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99     True
# Name: Gender, Length: 100, dtype: bool

# %% [markdown]
# 📋 Using Boolean Vectors to Filter Rows
#
# We can pass this Boolean Series back into the original DataFrame to filter only those rows where the condition is True:

# %%
# Filter all rows where Gender is Female
bank[bank['Gender'] == 'Female']
# Out:
#     Employee  EducLev  JobGrade  YrHired  YrBorn  Gender  YrsPrior PCJob  \
# 0          1        5         5     1991    1932  Female         0    No
# 1          2        6         1     1991    1931  Female         9    No
# 4          5        6         1     2011    1987  Female         1    No
# 5          6        3         4     2008    1979  Female         5    No
# 7          8        4         3     2017    1997  Female         7    No
# 9         10        6         3     1971    1929  Female         0   Yes
# 11        12        4         1     1961    1903  Female         4    No
# 13        14        6         5     2008    1971  Female         6    No
# 16        17        7         1     2015    1965  Female         2   Yes
# 17        18        7         4     1976    1923  Female         4    No
# 19        20        5         4     2008    1985  Female         8    No
# 21        22        2         1     1961    1920  Female         0    No
# ...

# %% [markdown]
# 📊 Analyze the filtered data
#
# Now, let’s find the average salary of female employees:

# %%
# Mean salary of female employees
FemaleEmployees['Salary'].mean()
# Out:
# np.float64(45.67878787878787)

# %%
round(FemaleEmployees['Salary'].mean(), 2)
# Out:
# np.float64(45.68)

# %% [markdown]
# # 3.3. Complex Filtering Criteria 🔍🔗
#
# Sometimes, you need to filter using **multiple conditions**. In Pandas, this is done using:
#
# - `&` (logical **AND**)
# - `|` (logical **OR**)
#
# ⚠️ **Important:** Wrap each condition in **parentheses**, or you’ll get an error.
#
# ### 🔧 Example: Female employees with JobGrade 1

# %% [markdown]
# This gives a Boolean Series where only those matching both conditions are marked True.

# %%
# Apply filter and view shape
bank[(bank['Gender'] == 'Female') & (bank['JobGrade'] == 1)].shape
# Out:
# (10, 9)

# %% [markdown]
# That means there are 48 female employees with JobGrade 1.

# %% [markdown]
# #3.4. Filtering by a List
#
# Let’s say you want to include employees in multiple categories — like all managerial staff (JobGrades 4, 5, and 6). You can do this in two ways:

# %%
# Select employees with JobGrade 4 or higher
bank[bank['JobGrade'] >= 4]
# Out:
#     Employee  EducLev  JobGrade  YrHired  YrBorn  Gender  YrsPrior PCJob  \
# 0          1        5         5     1991    1932  Female         0    No
# 5          6        3         4     2008    1979  Female         5    No
# 13        14        6         5     2008    1971  Female         6    No
# 17        18        7         4     1976    1923  Female         4    No
# 19        20        5         4     2008    1985  Female         8    No
# 22        23        5         6     1987    1961    Male         3    No
# 23        24        3         5     2013    1977    Male         4    No
# 25        26        6         4     1996    1960    Male         9   Yes
# 26        27        5         6     1991    1959    Male         4    No
# 30        31        6         4     1973    1922    Male         7    No
# 31        32        6         4     1970    1923    Male         1    No
# 34        35        5         6     1976    1940    Male         6    No
# ...

# %% [markdown]
# Method 2: Use a list and isin() — more flexible and works with categorical data

# %%
# Create a list of grades
mgmt = [4, 5, 6]

# Use isin() for filtering
bank[bank['JobGrade'].isin(mgmt)]
# Out:
#     Employee  EducLev  JobGrade  YrHired  YrBorn  Gender  YrsPrior PCJob  \
# 0          1        5         5     1991    1932  Female         0    No
# 5          6        3         4     2008    1979  Female         5    No
# 13        14        6         5     2008    1971  Female         6    No
# 17        18        7         4     1976    1923  Female         4    No
# 19        20        5         4     2008    1985  Female         8    No
# 22        23        5         6     1987    1961    Male         3    No
# 23        24        3         5     2013    1977    Male         4    No
# 25        26        6         4     1996    1960    Male         9   Yes
# 26        27        5         6     1991    1959    Male         4    No
# 30        31        6         4     1973    1922    Male         7    No
# 31        32        6         4     1970    1923    Male         1    No
# 34        35        5         6     1976    1940    Male         6    No
# ...

# %% [markdown]
# This returns the same result — a filtered DataFrame of managerial employees.

# %%
(bank['Gender'] == 'Male') | (bank['JobGrade'] > 4)
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4     False
#       ...
# 95     True
# 96     True
# 97     True
# 98     True
# 99     True
# Length: 100, dtype: bool

# %%
bank[bank['JobGrade'].isin([2, 3])]
# Out:
#     Employee  EducLev  JobGrade  YrHired  YrBorn  Gender  YrsPrior PCJob  \
# 6          7        4         3     2008    1956    Male         8    No
# 7          8        4         3     2017    1997  Female         7    No
# 9         10        6         3     1971    1929  Female         0   Yes
# 10        11        5         3     1998    1953    Male         6    No
# 12        13        7         3     1962    1921    Male         5    No
# 14        15        3         2     1996    1968    Male         2    No
# 15        16        5         2     2008    1971    Male         9    No
# 20        21        6         2     1961    1940    Male         4    No
# 24        25        7         3     1982    1956    Male         9    No
# 27        28        2         3     1992    1949    Male         6    No
# 28        29        2         3     1960    1917  Female         0    No
# 29        30        5         2     1993    1961    Male         3    No
# ...

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 4 Recoding Data
# #  4.1 Preliminaries

# %%
import pandas as pd
import numpy as np

# Load the data
bank = pd.read_csv('Data/Bank.csv')

# %% [markdown]
# # 4.2 Appending a Column
# You can append a new column (also called a Series in pandas) like this:

# %%
bank['Dummy'] = 0
bank.head()
# Out:
#    Employee  EducLev  JobGrade  YrHired  YrBorn  Gender  YrsPrior PCJob  \
# 0         1        5         5     1991    1932  Female         0    No
# 1         2        6         1     1991    1931  Female         9    No
# 2         3        4         1     1983    1934    Male         9    No
# 3         4        6         1     2000    1944    Male         0    No
# 4         5        6         1     2011    1987  Female         1    No
#
#    Salary  Dummy
# 0    44.6      0
# 1    47.1      0
# 2    42.2      0
# 3    38.3      0
# 4    43.6      0

# %% [markdown]
# You’ll see a new column Dummy filled with zeroes.

# %% [markdown]
# 🧹 Dropping a Column
#
# To remove the column again:

# %%
bank.drop('Dummy', axis=1, inplace=True)
bank.head()
# Out:
#    Employee  EducLev  JobGrade  YrHired  YrBorn  Gender  YrsPrior PCJob  \
# 0         1        5         5     1991    1932  Female         0    No
# 1         2        6         1     1991    1931  Female         9    No
# 2         3        4         1     1983    1934    Male         9    No
# 3         4        6         1     2000    1944    Male         0    No
# 4         5        6         1     2011    1987  Female         1    No
#
#    Salary
# 0    44.6
# 1    47.1
# 2    42.2
# 3    38.3
# 4    43.6

# %% [markdown]
# *   axis=1 tells pandas to drop a column (use 0 for rows).
# *   inplace=True means changes are saved directly to the DataFrame

# %% [markdown]
# #4.3 Recoding Using the Ternary Operator
#
# Trying to use a ternary operation on an entire pandas column like this won’t work:

# %%
# ❌ Invalid
1 if bank['Gender'] == "Female" else 0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-126-c10bc0e2b5e9> in <cell line: 0>()
#       1 # ❌ Invalid
# ----> 2 1 if bank['Gender'] == "Female" else 0
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# ##4.3.1 Using np.where()

# %%
bank['GenderDummy_F'] = np.where(bank['Gender'] == "Female", 1, 0)
bank.head()
# Out:
#    Employee  EducLev  JobGrade  YrHired  YrBorn  Gender  YrsPrior PCJob  \
# 0         1        5         5     1991    1932  Female         0    No
# 1         2        6         1     1991    1931  Female         9    No
# 2         3        4         1     1983    1934    Male         9    No
# 3         4        6         1     2000    1944    Male         0    No
# 4         5        6         1     2011    1987  Female         1    No
#
#    Salary  GenderDummy_F
# 0    44.6              1
# 1    47.1              1
# 2    42.2              0
# 3    38.3              0
# 4    43.6              1

# %% [markdown]
# This creates a new column GenderDummy_F, where:
#
#
#
# *   1 → Female
# *   0 → Male

# %% [markdown]
#  ##4.3.2 Using .apply() with a Function
#
# First, define a custom function:

# %%
def my_recode(gender):
    if gender == "Female":
        return 1
    else:
        return 0

# Test
print(my_recode("Female"), my_recode("Male"))  # Output: (1, 0)
# Out:
# 1 0

# %%
# Now apply
bank['GenderDummy_F'] = bank['Gender'].apply(my_recode)
bank.head()
# Out:
#    Employee  EducLev  JobGrade  YrHired  YrBorn  Gender  YrsPrior PCJob  \
# 0         1        5         5     1991    1932  Female         0    No
# 1         2        6         1     1991    1931  Female         9    No
# 2         3        4         1     1983    1934    Male         9    No
# 3         4        6         1     2000    1944    Male         0    No
# 4         5        6         1     2011    1987  Female         1    No
#
#    Salary  GenderDummy_F
# 0    44.6              1
# 1    47.1              1
# 2    42.2              0
# 3    38.3              0
# 4    43.6              1

# %% [markdown]
# ##4.3.3 Using a Lambda Function
#
# This is a more concise version of the .apply() technique:

# %%
bank['GenderDummy_F'] = bank['Gender'].apply(lambda x: 1 if x == "Female" else 0)
bank.head()
# Out:
#    Employee  EducLev  JobGrade  YrHired  YrBorn  Gender  YrsPrior PCJob  \
# 0         1        5         5     1991    1932  Female         0    No
# 1         2        6         1     1991    1931  Female         9    No
# 2         3        4         1     1983    1934    Male         9    No
# 3         4        6         1     2000    1944    Male         0    No
# 4         5        6         1     2011    1987  Female         1    No
#
#    Salary  GenderDummy_F
# 0    44.6              1
# 1    47.1              1
# 2    42.2              0
# 3    38.3              0
# 4    43.6              1

# %%
# Example 1
# Create a Dummy Variable for PCJob == "Yes"
# 1 = Yes, 0 = No
bank['PCJobDummy'] = np.where(bank['PCJob'] == "Yes", 1, 0)
bank[['PCJob', 'PCJobDummy']].head(10)
# Out:
#   PCJob  PCJobDummy
# 0    No           0
# 1    No           0
# 2    No           0
# 3    No           0
# 4    No           0
# 5    No           0
# 6    No           0
# 7    No           0
# 8    No           0
# 9   Yes           1

# %%
# Flag Employees Hired After 1990
# Flag employees hired after 1990
bank['HiredPost1990'] = bank['YrHired'].apply(lambda x: 1 if x > 90 else 0)
bank[['YrHired', 'HiredPost1990']].head(10)
# Out:
#    YrHired  HiredPost1990
# 0     1991              1
# 1     1991              1
# 2     1983              1
# 3     2000              1
# 4     2011              1
# 5     2008              1
# 6     2008              1
# 7     2017              1
# 8     2011              1
# 9     1971              1

# %%
# Flag Employees Born Before 1960
bank['BornBefore1960'] = np.where(bank['YrBorn'] < 60, 1, 0)
bank[['YrBorn', 'BornBefore1960']].head(10)
# Out:
#    YrBorn  BornBefore1960
# 0    1932               0
# 1    1931               0
# 2    1934               0
# 3    1944               0
# 4    1987               0
# 5    1979               0
# 6    1956               0
# 7    1997               0
# 8    1985               0
# 9    1929               0

# %%
#  Create a “SeniorManager” Column
# Let’s define senior managers as those with a JobGrade ≥ 5.
bank['SeniorManager'] = bank['JobGrade'].apply(lambda x: 1 if x >= 5 else 0)
bank[['JobGrade', 'SeniorManager']].head(10)
# Out:
#    JobGrade  SeniorManager
# 0         5              1
# 1         1              0
# 2         1              0
# 3         1              0
# 4         1              0
# 5         4              0
# 6         3              0
# 7         3              0
# 8         1              0
# 9         3              0

# %%
#Combine Multiple Conditions
# Let’s flag female senior managers.
bank['FemaleSrMgr'] = np.where(
    (bank['Gender'] == 'Female') & (bank['JobGrade'] >= 5),
    1,
    0
)
bank[['Gender', 'JobGrade', 'FemaleSrMgr']].head(10)
# Out:
#    Gender  JobGrade  FemaleSrMgr
# 0  Female         5            1
# 1  Female         1            0
# 2    Male         1            0
# 3    Male         1            0
# 4  Female         1            0
# 5  Female         4            0
# 6    Male         3            0
# 7  Female         3            0
# 8    Male         1            0
# 9  Female         3            0

# %%
# Categorize Salary Bands
# Let’s categorize salaries into Low, Medium, and High.
def salary_band(salary):
    if salary < 35:
        return 'Low'
    elif 35 <= salary < 60:
        return 'Medium'
    else:
        return 'High'

bank['SalaryBand'] = bank['Salary'].apply(salary_band)
bank[['Salary', 'SalaryBand']].head(10)
# Out:
#    Salary SalaryBand
# 0    44.6     Medium
# 1    47.1     Medium
# 2    42.2     Medium
# 3    38.3     Medium
# 4    43.6     Medium
# 5    41.4     Medium
# 6    42.2     Medium
# 7    46.2     Medium
# 8    41.1     Medium
# 9    51.9     Medium

# %%
# You can now use .value_counts() to check the distribution:
bank['SalaryBand'].value_counts()
# Out:
# SalaryBand
# Medium    100
# Name: count, dtype: int64

# %%
# Bucket Ages into Ranges
# Assume current year is 2025. Let's estimate age and categorize them.
bank['Age'] = 2025 - (1900 + bank['YrBorn'])

def age_group(age):
    if age < 30:
        return 'Young'
    elif 30 <= age < 50:
        return 'Mid-career'
    else:
        return 'Senior'

bank['AgeGroup'] = bank['Age'].apply(age_group)
bank[['YrBorn', 'Age', 'AgeGroup']].head(10)
# Out:
#    YrBorn   Age AgeGroup
# 0    1932 -1807    Young
# 1    1931 -1806    Young
# 2    1934 -1809    Young
# 3    1944 -1819    Young
# 4    1987 -1862    Young
# 5    1979 -1854    Young
# 6    1956 -1831    Young
# 7    1997 -1872    Young
# 8    1985 -1860    Young
# 9    1929 -1804    Young

# %%
# Boolean Masking with isin()
# Suppose we want to flag employees in JobGrades 2, 3, or 4.

target_grades = [2, 3, 4]
bank['MidMgr'] = bank['JobGrade'].isin(target_grades).astype(int)
bank[['JobGrade', 'MidMgr']].head(10)
# Out:
#    JobGrade  MidMgr
# 0         5       0
# 1         1       0
# 2         1       0
# 3         1       0
# 4         1       0
# 5         4       1
# 6         3       1
# 7         3       1
# 8         1       0
# 9         3       1

# %%
# Create a Gender Label Column
bank['GenderLabel'] = bank['GenderDummy_F'].apply(lambda x: 'Female' if x == 1 else 'Male')
bank[['GenderDummy_F', 'GenderLabel']].head(10)
# Out:
#    GenderDummy_F GenderLabel
# 0              1      Female
# 1              1      Female
# 2              0        Male
# 3              0        Male
# 4              1      Female
# 5              1      Female
# 6              0        Male
# 7              1      Female
# 8              0        Male
# 9              1      Female

# %% [markdown]
# #4.4 – Replacing Values from a List
#
# map values in a column to new values using replace() method in pandas with lists.

# %%
import pandas as pd

# Load dataset
bank = pd.read_csv('Data/Bank.csv')

# %% [markdown]
# #Example: Replace Job Grades with Managerial Status

# %%
grades = [1, 2, 3, 4, 5, 6]
status = ["non-mgmt", "non-mgmt", "non-mgmt", "non-mgmt", "mgmt", "mgmt"]

# Create a new column 'Manager' using replace()
bank['Manager'] = bank['JobGrade'].replace(grades, status)

# Preview specific rows
bank[10:75]
# Out:
#     Employee  EducLev  JobGrade  YrHired  YrBorn  Gender  YrsPrior PCJob  \
# 10        11        5         3     1998    1953    Male         6    No
# 11        12        4         1     1961    1903  Female         4    No
# 12        13        7         3     1962    1921    Male         5    No
# 13        14        6         5     2008    1971  Female         6    No
# 14        15        3         2     1996    1968    Male         2    No
# ..       ...      ...       ...      ...     ...     ...       ...   ...
# 70        71        6         3     1974    1931    Male         5    No
# 71        72        3         3     2007    1971  Female         9    No
# 72        73        6         5     1980    1958    Male         3    No
# 73        74        2         3     2015    1986  Female         5    No
# 74        75        6         5     1993    1962    Male         4    No
#
#     Salary   Manager
# 10    48.0  non-mgmt
# 11    43.0  non-mgmt
# 12    50.4  non-mgmt
# ...

# %% [markdown]
# #4.4 – Replacing Values from a List
#
#  map values in a column to new values using replace() method in pandas with lists.

# %%
import pandas as pd

# Load dataset
bank = pd.read_csv('Data/Bank.csv')

# %% [markdown]
# Replace Job Grades with Managerial Status

# %%
grades = [1, 2, 3, 4, 5, 6]
status = ["non-mgmt", "non-mgmt", "non-mgmt", "non-mgmt", "mgmt", "mgmt"]

# Create a new column 'Manager' using replace()
bank['Manager'] = bank['JobGrade'].replace(grades, status)

# Preview specific rows
bank[70:75]
# Out:
#     Employee  EducLev  JobGrade  YrHired  YrBorn  Gender  YrsPrior PCJob  \
# 70        71        6         3     1974    1931    Male         5    No
# 71        72        3         3     2007    1971  Female         9    No
# 72        73        6         5     1980    1958    Male         3    No
# 73        74        2         3     2015    1986  Female         5    No
# 74        75        6         5     1993    1962    Male         4    No
#
#     Salary   Manager
# 70    47.2  non-mgmt
# 71    46.3  non-mgmt
# 72    50.8      mgmt
# 73    42.1  non-mgmt
# 74    51.8      mgmt

# %% [markdown]
# The lists must be of equal length.
#
# Each index in grades maps to the same index in status.
#
# The original column (JobGrade) remains unchanged unless inplace=True is used.

# %% [markdown]
# Recode Gender Using Replace

# %%
genders = ["Female", "Male"]
dummy_vars = [1, 0]

bank['GenderDummy_F'] = bank['Gender'].replace(genders, dummy_vars)

# Preview results
bank.head()
# Out:
# <ipython-input-8-942fb0ebafab>:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bank['GenderDummy_F'] = bank['Gender'].replace(genders, dummy_vars)
#    Employee  EducLev  JobGrade  YrHired  YrBorn  Gender  YrsPrior PCJob  \
# 0         1        5         5     1991    1932  Female         0    No
# 1         2        6         1     1991    1931  Female         9    No
# 2         3        4         1     1983    1934    Male         9    No
# 3         4        6         1     2000    1944    Male         0    No
# 4         5        6         1     2011    1987  Female         1    No
#
#    Salary   Manager  GenderDummy_F
# 0    44.6      mgmt              1
# 1    47.1  non-mgmt              1
# 2    42.2  non-mgmt              0
# ...

# %% [markdown]
# Examples

# %% [markdown]
# Create a new column for Education Level Labels

# %% [markdown]
# Using the replace() method to convert numeric education levels into human-readable strings.

# %%
# Example mapping
education_levels = [1, 2, 3, 4, 5]
education_labels = ['High School', 'Associate', 'Bachelor', 'Master', 'Doctorate']

# Replace and create new column
bank['EducationLabel'] = bank['EducLev'].replace(education_levels, education_labels)
bank[['EducLev', 'EducationLabel']].head()
# Out:
#    EducLev EducationLabel
# 0        5      Doctorate
# 1        6              6
# 2        4         Master
# 3        6              6
# 4        6              6

# %% [markdown]
#  Categorize hiring decade from YrHired

# %% [markdown]
# Group years into decades for easier analysis (e.g., 70s, 80s, 90s).

# %%
# Map hire years into decade labels
decade_years = [70, 80, 90]
decade_labels = ['1970s', '1980s', '1990s']

# Convert YrHired to decade group
bank['HireDecade'] = bank['YrHired'].replace([i for i in range(70, 80)] +
                                             [i for i in range(80, 90)] +
                                             [i for i in range(90, 100)],
                                             ['1970s'] * 10 + ['1980s'] * 10 + ['1990s'] * 10)
bank[['YrHired', 'HireDecade']].head()
# Out:
#    YrHired  HireDecade
# 0     1991        1991
# 1     1991        1991
# 2     1983        1983
# 3     2000        2000
# 4     2011        2011

# %% [markdown]
# Create a Dummy Variable for PCJob

# %% [markdown]
# Turn "Yes"/"No" in the PCJob column into binary values (1 for Yes, 0 for No).

# %%
# Map Yes/No to 1/0
bank['PCJobDummy'] = bank['PCJob'].replace(['Yes', 'No'], [1, 0])
bank[['PCJob', 'PCJobDummy']].head()
# Out:
# <ipython-input-14-98c64856617c>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bank['PCJobDummy'] = bank['PCJob'].replace(['Yes', 'No'], [1, 0])
#   PCJob  PCJobDummy
# 0    No           0
# 1    No           0
# 2    No           0
# 3    No           0
# 4    No           0

# %% [markdown]
#  Assign Age Group based on YrBorn
#
# Use birth year to classify individuals into age brackets.

# %%
# Sample age group mapping (assumes data from 2000s)
birth_years = [i for i in range(40, 51)] + [i for i in range(51, 61)] + [i for i in range(61, 71)]
age_groups = ['60+', '50s', '40s'] * 10  # adjust this list accordingly to match length

# Replace with group labels (manual slicing)
bank['AgeGroup'] = bank['YrBorn'].replace(
    [i for i in range(40, 50)] + [i for i in range(50, 60)] + [i for i in range(60, 70)],
    ['60+', '50s', '40s'] * 10
)
bank[['YrBorn', 'AgeGroup']].head()
# Out:
#    YrBorn  AgeGroup
# 0    1932      1932
# 1    1931      1931
# 2    1934      1934
# 3    1944      1944
# 4    1987      1987

# %% [markdown]
# Multiple Column Replacements (Challenge)

# %% [markdown]
# #4.5 – Logging Variables

# %%
import numpy as np
import seaborn as sns
import pandas as pd

# Load dataset
bank = pd.read_csv('Data/Bank.csv')

# %% [markdown]
# Log-transforming Salary

# %%
# Apply natural log to the Salary column
bank['logSalary'] = np.log(bank['Salary'])

# Preview the data
bank[['Salary', 'logSalary']].head()
# Out:
#    Salary  logSalary
# 0    44.6   3.797734
# 1    47.1   3.852273
# 2    42.2   3.742420
# 3    38.3   3.645450
# 4    43.6   3.775057

# %% [markdown]
# Visualize the Distribution

# %%
# Plot kernel density estimate (KDE)
sns.kdeplot(x=bank['logSalary'], shade=True, linewidth=2)
# Out:
# <ipython-input-11-7d57b76d2195>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=bank['logSalary'], shade=True, linewidth=2)
# <Axes: xlabel='logSalary', ylabel='Density'>

# %% [markdown]
# np.log() is the natural log (base e).
#
# Log transforms are commonly used to reduce skewness or normalize distributions.
#
# In this dataset, bimodality remains due to different salary groups (workers vs. managers).

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# #5 – Gap Analysis with Continuous Variables
#
#
#  ## 5.1 Preliminaries
#  ## 5.2 Visual Gap Analysis

# %%
import seaborn as sns

# Compare salary distributions for each gender
sns.boxplot(y=bank['Salary'], x=bank['Gender'], showmeans=True)
# Out:
# <Axes: xlabel='Gender', ylabel='Salary'>

# %% [markdown]
# Boxplot of Salary by JobGrade (as a category)

# %%
# Convert JobGrade to category on the fly for proper boxplot grouping
sns.boxplot(x=bank['Salary'], y=bank['JobGrade'].astype('category'), showmeans=True)
# Out:
# <Axes: xlabel='Salary', ylabel='JobGrade'>

# %% [markdown]
# JobGrade was initially left as an integer. Converting it to a categorical variable allows meaningful boxplots.
#
# Higher job grades tend to have higher salaries and more variability in salaries.

# %% [markdown]
# #5.3 – Histograms and Kernel Density Plots
#
# ##5.3.1 – Faceted Histograms

# %% [markdown]
#  Salary Distribution by Gender Using Facets

# %%
# Faceted histogram by gender
sns.displot(x='Salary', row='Gender', data=bank, linewidth=0, kde=True)

# %% [markdown]
# This creates a grid of histograms — one row per gender.
#
# Kernel Density Estimates (KDEs) are included for smoother interpretation.

# %% [markdown]
# ##5.3.2 – Overlayed Kernel Density Plots

# %% [markdown]
# Overlayed Histogram by Gender

# %%
# Overlayed histogram (with overlapping colors)
sns.histplot(x='Salary', hue='Gender', data=bank, linewidth=0)
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %% [markdown]
# Overlapping histograms can be hard to interpret due to color blending.
#
# Better for quick visual comparisons but not ideal for detailed insights.

# %% [markdown]
# ###Overlayed KDE Plot (Recommended)

# %%
# Recommended: overlayed KDE with shading
sns.kdeplot(x='Salary', hue='Gender', data=bank, shade=True)
# Out:
# <ipython-input-22-e6535838c952>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x='Salary', hue='Gender', data=bank, shade=True)
# <Axes: xlabel='Salary', ylabel='Density'>

# %% [markdown]
# KDEs provide a smooth approximation of the salary distributions.
#
# Shading enhances visual appeal and clarity.
#
# Useful for detecting gaps or overlaps in distributions.

# %% [markdown]
# #5.4 – t-Tests

# %% [markdown]
# ##5.4.1 – Formatting the Data
#
# Extracting Salary Data for Female and Male Employees

# %%
# Filter and extract salary data for female employees
female_sal = bank[bank['Gender'] == "Female"]['Salary']

# Filter and extract salary data for male employees
male_sal = bank[bank['Gender'] == "Male"]['Salary']

# %% [markdown]
# You start by filtering the bank DataFrame using Boolean conditions.
#
# The condition bank['Gender'] == "Female" returns a Boolean Series.
#
# This Boolean Series is used to subset the data frame.
#
# The ['Salary'] selector pulls the relevant numeric column into a separate vector.

# %% [markdown]
# #5.5 – Testing for Equality of Variance

# %%
# Import the Levene's test function from SciPy
from scipy import stats

# Perform Levene’s test
stats.levene(female_sal, male_sal)
# Out:
# LeveneResult(statistic=np.float64(1.577773697255916), pvalue=np.float64(0.2120679057091148))

# %% [markdown]
# Levene’s test checks for equality of variances between two samples.
#
# A very small p-value (e.g., 7.01e-07) suggests that the variances are significantly different.
#
# Since SciPy does not support F-tests, Levene’s test is used as a robust alternative.
#
# Proceed with unequal variance assumption when the p-value is very low.

# %% [markdown]
# #5.6 – Running the t-Test
#
# two-sample t-test in Python using the statsmodels library to check if the difference in mean salaries is statistically significant.

# %%
# Import the CompareMeans tool from statsmodels
import statsmodels.stats.api as sms

# Create the t-test model
model = sms.CompareMeans.from_data(female_sal, male_sal)

# Display the summary with unequal variance assumption
model.summary(usevar='unequal')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# #6 – Gap Analysis with Categorical Variables
#
# ## 6.1. Preliminaries

# %%
# Import libraries
import pandas as pd
from scipy import stats

# Load the dataset
bank = pd.read_csv('Data/Bank.csv')

# Recode JobGrade to a binary Manager status
grades = [1, 2, 3, 4, 5, 6]
status = ["non-mgmt", "non-mgmt", "non-mgmt", "non-mgmt", "mgmt", "mgmt"]
bank['Manager'] = bank['JobGrade'].replace(grades, status)

# Display first few rows
bank.head()
# Out:
#    Employee  EducLev  JobGrade  YrHired  YrBorn  Gender  YrsPrior PCJob  \
# 0         1        5         5     1991    1932  Female         0    No
# 1         2        6         1     1991    1931  Female         9    No
# 2         3        4         1     1983    1934    Male         9    No
# 3         4        6         1     2000    1944    Male         0    No
# 4         5        6         1     2011    1987  Female         1    No
#
#    Salary   Manager
# 0    44.6      mgmt
# 1    47.1  non-mgmt
# 2    42.2  non-mgmt
# 3    38.3  non-mgmt
# 4    43.6  non-mgmt

# %% [markdown]
# #6.2. Creating a Contingency Table
#
# Contingency tables show the frequency distribution of variables. Below we compare Gender and Manager status using pd.crosstab().

# %%
contab_freq = pd.crosstab(
    bank['Gender'],
    bank['Manager'],
    margins=True
)
contab_freq
# Out:
# Manager  mgmt  non-mgmt  All
# Gender
# Female      7        26   33
# Male       13        54   67
# All        20        80  100

# %% [markdown]
# margins=True adds totals (like "All") for rows and columns.
#
# This helps visualize raw counts across categories.

# %% [markdown]
# #6.3. Showing Row Percentages
#
# Raw counts can be misleading when the groups have different sizes. Instead, row-wise percentages help us understand within-group distributions.

# %%
conttab_relfreq = pd.crosstab(
    bank['Gender'],
    bank['Manager'],
    margins=True,
    normalize='index'  # Normalize rows
)
conttab_relfreq
# Out:
# Manager      mgmt  non-mgmt
# Gender
# Female   0.212121  0.787879
# Male     0.194030  0.805970
# All      0.200000  0.800000

# %% [markdown]
# #6.4. Chi-Squared Test of Independence
#
#
# We test if Gender and Managerial Status are independent using the Chi-Squared Test.
#
# - The null hypothesis (H₀): Gender and Managerial status are independent.

# %%
contab_obs = pd.crosstab(
    bank['Gender'],
    bank['Manager'],
    margins=False  # Don't include totals
)

chi = stats.chi2_contingency(contab_obs)
chi
# Out:
# Chi2ContingencyResult(statistic=np.float64(0.0), pvalue=np.float64(1.0), dof=1, expected_freq=array([[ 6.6, 26.4],
#        [13.4, 53.6]]))

# %% [markdown]
# - Chi-square statistic: test value (ignore for now)
#
# - p-value: tells us if the relationship is statistically significant
#
# - degrees of freedom: (rows - 1) * (cols - 1)
#
# - expected frequencies: what we’d expect if there were no relationship
#
# -- The p-value is extremely small (< 0.000001)
#
# -- We reject H₀ ⇒ Gender and Managerial status are not independent

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# #7. Correlation and Scatterplots
#
# ##7.1 Preliminaries

# %%
import pandas as pd

# Load the dataset
con = pd.read_csv('Data/ConcreteStrength.csv')
con.head()
# Out:
#    Cement   Slag  Fly ash  Water    SP  Coarse Aggr.  Fine Aggr.  \
# 0   224.9    4.7     96.3  126.7   6.5         939.6       633.8
# 1   340.1   95.5     12.6  189.1  18.5         907.2       655.7
# 2   296.4   47.2     24.2  190.3  12.6         861.9       635.4
# 3   269.7   76.3    134.8  202.9  17.4         962.8       617.7
# 4   181.2  136.1     91.0  214.4   9.8         936.9       624.1
#
#   Air Entrainment  Compressive Strength (28-day)(Mpa)
# 0             Yes                              24.676
# 1             Yes                              57.593
# 2             Yes                              45.108
# 3              No                              33.396
# 4              No                              25.571

# %% [markdown]
# #7.2 Renaming Columns
#
# **Why rename?**
#
# Column names may contain spaces or special characters, making them harder to work with in code. Rather than modifying the source file, it's more practical to fix column names in the DataFrame.

# %%
# View existing column names
list(con.columns)
# Out:
# ['Cement',
#  'Slag',
#  'Fly ash',
#  'Water',
#  'SP',
#  'Coarse Aggr.',
#  'Fine Aggr.',
#  'Air Entrainment',
#  'Compressive Strength (28-day)(Mpa)']

# %%
# Rename problematic columns
con.rename(columns={
    'Fly ash': 'FlyAsh',
    'Coarse Aggr.': 'CoarseAgg',
    'Fine Aggr.': 'FineAgg',
    'Air Entrainment': 'AirEntrain',
    'Compressive Strength (28-day)(Mpa)': 'Strength'
}, inplace=True)

# Preview the updated DataFrame
con.head()
# Out:
#    Cement   Slag  FlyAsh  Water    SP  CoarseAgg  FineAgg AirEntrain  Strength
# 0   224.9    4.7    96.3  126.7   6.5      939.6    633.8        Yes    24.676
# 1   340.1   95.5    12.6  189.1  18.5      907.2    655.7        Yes    57.593
# 2   296.4   47.2    24.2  190.3  12.6      861.9    635.4        Yes    45.108
# 3   269.7   76.3   134.8  202.9  17.4      962.8    617.7         No    33.396
# 4   181.2  136.1    91.0  214.4   9.8      936.9    624.1         No    25.571

# %%
# Convert obvious categorical variables
con['AirEntrain'] = con['AirEntrain'].astype('category')
con.describe(include='category')
# Out:
#        AirEntrain
# count          80
# unique          2
# top            No
# freq           44

# %% [markdown]
# #7.3 Scatterplots
#
# A scatterplot is a basic but powerful way to visualize the relationship between two continuous variables.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Scatterplot using Seaborn
sns.scatterplot(x="FlyAsh", y="Strength", data=con);

# %% [markdown]
# #7.4 Adding Labels to Scatterplot
#
# You can assign the plot object to a variable and customize its title and labels.

# %%
ax = sns.scatterplot(x="FlyAsh", y="Strength", data=con)
ax.set_title("Concrete Strength vs. Fly Ash")
ax.set_xlabel("Fly Ash");
ax.set_ylabel("Compressive Strength (MPa)");

# %% [markdown]
# #7.5 Adding a Best Fit Line
#
# To add a regression line with confidence intervals, use lmplot:

# %%
sns.lmplot(x="FlyAsh", y="Strength", data=con);

# %% [markdown]
# #7.6 Adding Color as a Third Dimension
#
# Use hue to include a categorical variable in the visualization (e.g., AirEntrainment).

# %%
sns.lmplot(x="FlyAsh", y="Strength", hue="AirEntrain", data=con);

# %% [markdown]
# #7.7 Correlation Coefficient
#
# A Pearson correlation coefficient describes the linear relationship between two variables.

# %%
from scipy import stats

# Pearson's correlation and p-value
stats.pearsonr(con['Strength'], con['FlyAsh'])
# Out:
# PearsonRResult(statistic=np.float64(-0.13715047205421932), pvalue=np.float64(0.2250736748134836))

# %% [markdown]
# The result returns a tuple:
#
# - Correlation coefficient (r): How strong is the linear relationship?
#
# - P-value: Probability the true correlation is 0.

# %% [markdown]
# #7.8 Correlation Matrix
#
# Compute the pairwise correlations among all numeric variables:

# %%
# Convert categorical columns to numeric using one-hot encoding
con_encoded = pd.get_dummies(con, drop_first=True)

# Now compute correlation matrix
cormat = con_encoded.corr()

# Round to 2 decimal places
cormat_rounded = cormat.round(2)

print(cormat_rounded)
# Out:
#                 Cement  Slag  FlyAsh  Water    SP  CoarseAgg  FineAgg  \
# Cement            1.00 -0.06   -0.09  -0.16  0.12       0.01    -0.14
# Slag             -0.06  1.00   -0.19   0.09 -0.22       0.02     0.04
# FlyAsh           -0.09 -0.19    1.00  -0.13 -0.06      -0.04     0.01
# Water            -0.16  0.09   -0.13   1.00  0.12      -0.08    -0.30
# SP                0.12 -0.22   -0.06   0.12  1.00      -0.10     0.01
# CoarseAgg         0.01  0.02   -0.04  -0.08 -0.10       1.00    -0.19
# FineAgg          -0.14  0.04    0.01  -0.30  0.01      -0.19     1.00
# Strength          0.06 -0.07   -0.14   0.04  0.01       0.04     0.08
# AirEntrain_Yes   -0.06 -0.13    0.09  -0.05 -0.12      -0.07     0.05
#
#                 Strength  AirEntrain_Yes
# Cement              0.06           -0.06
# Slag               -0.07           -0.13
# FlyAsh             -0.14            0.09
# Water               0.04           -0.05
# SP                  0.01           -0.12
# ...

# %% [markdown]
# # 7.9 Correlation Matrix to Heatmap
# A heatmap visualizes the correlation matrix with colors.

# %%
# Visualize the correlation matrix
sns.heatmap(cormat, annot=True, cmap="coolwarm");

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# #8: Simple Linear Regression
#  Using statsmodels to build a simple linear regression model in Python

# %% [markdown]
#  # 8.1 Preliminaries

# %%
# Import necessary library
import pandas as pd

# Load the dataset
con = pd.read_csv('Data/ConcreteStrength.csv')

# Rename columns for easier access
con.rename(columns={
    'Fly ash': 'FlyAsh',
    'Coarse Aggr.': "CoarseAgg",
    'Fine Aggr.': 'FineAgg',
    'Air Entrainment': 'AirEntrain',
    'Compressive Strength (28-day)(Mpa)': 'Strength'
}, inplace=True)

# Convert 'AirEntrain' to categorical
con['AirEntrain'] = con['AirEntrain'].astype('category')

# Display the first few rows
con.head()
# Out:
#    Cement   Slag  FlyAsh  Water    SP  CoarseAgg  FineAgg AirEntrain  Strength
# 0   224.9    4.7    96.3  126.7   6.5      939.6    633.8        Yes    24.676
# 1   340.1   95.5    12.6  189.1  18.5      907.2    655.7        Yes    57.593
# 2   296.4   47.2    24.2  190.3  12.6      861.9    635.4        Yes    45.108
# 3   269.7   76.3   134.8  202.9  17.4      962.8    617.7         No    33.396
# 4   181.2  136.1    91.0  214.4   9.8      936.9    624.1         No    25.571

# %% [markdown]
# #8.2 Linear Regression with a Single Explanatory Variable
#
# We're using statsmodels' OLS method (Ordinary Least Squares). It finds the line of best fit by minimizing squared residuals.

# %% [markdown]
# ##8.2.1 Preparing the Data

# %%
import statsmodels.api as sm

# Define the response (Y) and explanatory (X) variables
Y = con['Strength']
X = con['FlyAsh']

# Check X
X.head()
# Out:
# 0     96.3
# 1     12.6
# 2     24.2
# 3    134.8
# 4     91.0
# Name: FlyAsh, dtype: float64

# %% [markdown]
# - Y is a 1D vector (concrete strength), and X is a 1D vector (amount of fly ash).
# - We'll now add a constant to X (which is the intercept term in our regression).

# %% [markdown]
# ##8.2.2 Adding a Column for the Constant

# %%
# Add constant (intercept)
X = sm.add_constant(X)

# View updated X matrix
X.head()
# Out:
#    const  FlyAsh
# 0    1.0    96.3
# 1    1.0    12.6
# 2    1.0    24.2
# 3    1.0   134.8
# 4    1.0    91.0

# %% [markdown]
# The constant is essential — it allows the model to learn the intercept of the regression line.

# %% [markdown]
# ##8.2.3 Running the Model

# %%
# Define the OLS regression model
model = sm.OLS(Y, X, missing='drop')

# Fit the model (estimate parameters)
model_result = model.fit()

# Show a summary of results
model_result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Strength   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     1.495
# Date:                Thu, 29 May 2025   Prob (F-statistic):              0.225
# Time:                        09:18:21   Log-Likelihood:                -292.78
# No. Observations:                  80   AIC:                             589.6
# Df Residuals:                      78   BIC:                             594.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         44.0243      1.917     22.966      0.000      40.208      47.841
# ...

# %% [markdown]
# #8.3: Regression Diagnostics
#
# In linear regression, **residuals** are the differences between actual values (**Y**) and predicted values from the model.
#
# \[
# \text{Residual} = Y_{\text{actual}} - Y_{\text{predicted}}
# \]
#
# A **key assumption** in linear regression is that residuals are:
#
# - Normally distributed
# - Centered around zero (mean = 0)
# - Randomly scattered (not patterned)
#
# If this assumption is violated (e.g., residuals are skewed, show patterns, or have unequal variance), then the linear regression model might not be valid.
#
# **Key Concept:** *Residuals should behave like noise.*
#
# Let's inspect residuals using `model_result.resid` from a regression model created using `statsmodels`.

# %%
# Assuming you already have a model_result from a fitted OLS model
residuals = model_result.resid
residuals[:5]  # show the first 5 residuals
# Out:
# 0   -16.528839
# 1    13.937588
# 2     1.792213
# 3    -6.681634
# 4   -15.789013
# dtype: float64

# %% [markdown]
# #8.4: Histogram of Residuals
#
# We can use **Seaborn** to visualize the distribution of residuals.
#
# This helps us check if the residuals are normally distributed.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(model_result.resid)
plt.title("Histogram of Residuals")
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# A more informative method is to:
#
# 1. Plot the residuals using a **kernel density estimate (KDE)**
# 2. Overlay a **normal distribution curve** that has the **same mean and standard deviation** as the residuals
#
# We'll use `scipy.stats.norm.fit()` to calculate the mean and standard deviation of the residuals.

# %%
from scipy import stats

# Fit a normal distribution to the residuals
mu, std = stats.norm.fit(model_result.resid)
mu, std
# Out:
# (np.float64(1.7763568394002506e-16), np.float64(9.400780962400038))

# %%
import numpy as np

fig, ax = plt.subplots()

# Plot residuals as a KDE histogram
sns.histplot(x=model_result.resid, ax=ax, stat="density", linewidth=0, kde=True)
ax.set(title="Distribution of Residuals", xlabel="Residual")

# Generate x values and the corresponding y values for the normal curve
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = stats.norm.pdf(x, mu, std)

# Plot the normal curve
sns.lineplot(x=x, y=p, color="orange", ax=ax)
plt.show()

# %% [markdown]
# # 8.5: Boxplot of Residuals
#
# A **boxplot** is a useful visualization when residuals are not normally distributed. It gives insights into:
#
# - The distribution of residuals (spread and skewness)
# - The median and mean of residuals (showing symmetry or skewness)
# - Potential outliers in residuals
#
# In the boxplot, if the **mean is close to the median**, it indicates the residuals are fairly symmetric.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=model_result.resid, showmeans=True)
plt.title("Boxplot of Residuals")
plt.xlabel("Residuals")
plt.show()

# %% [markdown]
# # 8.6: Q-Q Plot (Quantile-Quantile Plot)
#
# A **Q-Q plot** compares the quantiles of the residuals against the quantiles of a normal distribution.
#
# - If residuals are normally distributed, points in the Q-Q plot will lie roughly on the **45° reference line**.
# - Deviations from this line indicate deviations from normality.
#
# Statsmodels provides a convenient function to create this plot.
#
# Note: Q-Q plots are mainly for data analysts rather than stakeholders or decision makers.

# %%
import statsmodels.api as sm

sm.qqplot(model_result.resid, line='s')
plt.title("Q-Q Plot of Residuals")
plt.show()

# %% [markdown]
# # 8.7: Fit Plot (Predicted vs Actual)
#
# A **fit plot** compares predicted values from the model to the actual observed values.
#
# - If the model fits perfectly, all points fall on the **45° diagonal** (predicted = actual).
# - The quality of the model fit can be roughly assessed by how close the points are to this line.
#
# Statsmodels offers a quick way to generate this plot.

# %%
sm.graphics.plot_fit(model_result, 1, vlines=False)
plt.title("Fit Plot: Predicted vs Actual")
plt.show()

# %% [markdown]
# # 8.8: Improved Fit Plot with Seaborn
#
# Seaborn can create a more customized fit plot:
#
# Steps:
# 1. Find the min and max of the observed response variable \( Y \).
# 2. Get predicted values from the model.
# 3. Plot predicted vs observed values.
# 4. Set equal limits on both axes so the 45° line is meaningful.
# 5. Plot the 45° reference line to visually assess fit quality.
#
# This approach makes it easier to see how well the model predicts the actual data.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming Y is your observed response variable
Y_max = Y.max()
Y_min = Y.min()

# Predicted values from the model
predicted = model_result.fittedvalues

# Create scatterplot of predicted vs actual
ax = sns.scatterplot(x=predicted, y=Y)

# Set equal limits on both axes
ax.set_xlim(Y_min, Y_max)
ax.set_ylim(Y_min, Y_max)

# Label axes
ax.set_xlabel("Predicted value of Y")
ax.set_ylabel("Observed value of Y")

# Add 45 degree reference line
line_vals = np.linspace(Y_min, Y_max, 100)
plt.plot(line_vals, line_vals, color='red', linewidth=1)

plt.title("Observed vs Predicted Fit Plot")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 9. Multiple Linear Regression

# %% [markdown]
# # 9.1. Preliminaries
#
# Before we start with multiple linear regression, we need to:
#
# - Load the necessary libraries (Pandas and Statsmodels)
# - Read the data from a CSV file
# - Fix column names for easier access
# - Convert the categorical variable `AirEntrain` to a categorical type

# %%
import pandas as pd
import statsmodels.api as sm

# Load the data
con = pd.read_csv('Data/ConcreteStrength.csv')

# Rename columns to simpler names (remove spaces and special chars)
con.rename(columns={
    'Fly ash': 'FlyAsh',
    'Coarse Aggr.': 'CoarseAgg',
    'Fine Aggr.': 'FineAgg',
    'Air Entrainment': 'AirEntrain',
    'Compressive Strength (28-day)(Mpa)': 'Strength'
}, inplace=True)

# Convert AirEntrain to categorical data type
con['AirEntrain'] = con['AirEntrain'].astype('category')

# Show first 3 rows to verify changes
con.head(3)
# Out:
#    No  Cement  Slag  FlyAsh  Water    SP  CoarseAgg  FineAgg AirEntrain  \
# 0   1   224.9   4.7    96.3  126.7   6.5      939.6    633.8        Yes
# 1   2   340.1  95.5    12.6  189.1  18.5      907.2    655.7        Yes
# 2   3   296.4  47.2    24.2  190.3  12.6      861.9    635.4        Yes
#
#    Strength
# 0    24.676
# 1    57.593
# 2    45.108

# %% [markdown]
# **Separate dependent and independent variables**
#
# - Y contains the response variable (Strength)
#
# - X contains numerical explanatory variables (excluding categorical AirEntrain for now)

# %%
import statsmodels.api as sm

# List of columns you want to select
desired_columns = ['No', 'Cement', 'Slag', 'FlyAsh', 'Water', 'SP', 'CoarseAgg', 'FineAgg']

# Print all columns in the DataFrame
print("Available columns in DataFrame:")
print(con.columns.tolist())

# Check which desired columns are missing
missing_cols = [col for col in desired_columns if col not in con.columns]
if missing_cols:
    print(f"Warning: These columns are missing in the DataFrame: {missing_cols}")

# Use only the columns that exist
existing_cols = [col for col in desired_columns if col in con.columns]

# If 'No' is not a feature but an index, reset index (optional)
if 'No' not in existing_cols and con.index.name == 'No':
    con = con.reset_index()
    if 'No' in con.columns:
        existing_cols.append('No')

# Define predictors X and response Y
Y = con['Strength']  # Assuming 'Strength' column exists

X = con[existing_cols]

# Add constant term (intercept)
X = sm.add_constant(X)

print("Final predictor columns used:")
print(X.columns.tolist())
# Out:
# Available columns in DataFrame:
# ['No', 'Cement', 'Slag', 'FlyAsh', 'Water', 'SP', 'CoarseAgg', 'FineAgg', 'AirEntrain', 'Strength']
# Final predictor columns used:
# ['const', 'No', 'Cement', 'Slag', 'FlyAsh', 'Water', 'SP', 'CoarseAgg', 'FineAgg']

# %% [markdown]
# #9.2. Kitchen Sink Model
#
# Start with a "kitchen sink" model by including all numerical explanatory variables.

# %%
ks = sm.OLS(Y, X)
ks_res = ks.fit()

# Summary of the regression results
ks_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Strength   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                 -0.055
# Method:                 Least Squares   F-statistic:                    0.4853
# Date:                Thu, 29 May 2025   Prob (F-statistic):              0.863
# Time:                        13:37:21   Log-Likelihood:                -291.41
# No. Observations:                  80   AIC:                             600.8
# Df Residuals:                      71   BIC:                             622.3
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.5149     33.554      0.224      0.823     -59.390      74.419
# ...

# %% [markdown]
# #9.3. Categorical explanatory variables
#
# Handling categorical variables like AirEntrain requires special treatment:
#
# - Excel & SAS: manually create dummy columns (0/1 flags)
#
# - R: use factors which automatically create dummy variables
#
# - Python: either manual (create dummy variables yourself) or automatic (let libraries handle it)

# %% [markdown]
# ##9.3.1. Create dummy variables manually using
#
# pd.get_dummies()

# %%
AirEntrain_d = pd.get_dummies(con['AirEntrain'])
AirEntrain_d.head()
# Out:
#       No    Yes
# 0  False   True
# 1  False   True
# 2  False   True
# 3   True  False
# 4   True  False

# %% [markdown]
# Drop the "No" column to use it as the baseline and rename the other column for clarity:

# %%
AirEntrain_d.drop(columns='No', inplace=True)
AirEntrain_d.rename(columns={'Yes': 'AirEntrain_Yes'}, inplace=True)
AirEntrain_d.head(3)
# Out:
#    AirEntrain_Yes
# 0            True
# 1            True
# 2            True

# %% [markdown]
# ##9.3.2. Automated version with prefix and dropping first dummy

# %%
AirEntrain_d = pd.get_dummies(con['AirEntrain'], prefix='AirEntrain', drop_first=True)
AirEntrain_d.head(3)
# Out:
#    AirEntrain_Yes
# 0            True
# 1            True
# 2            True

# %% [markdown]
# ##9.3.3. Add dummy variables to original predictors

# %%
fullX = pd.concat([X, AirEntrain_d['AirEntrain_Yes']], axis=1)
fullX.head()
# Out:
#    const  No  Cement   Slag  FlyAsh  Water    SP  CoarseAgg  FineAgg  \
# 0    1.0   1   224.9    4.7    96.3  126.7   6.5      939.6    633.8
# 1    1.0   2   340.1   95.5    12.6  189.1  18.5      907.2    655.7
# 2    1.0   3   296.4   47.2    24.2  190.3  12.6      861.9    635.4
# 3    1.0   4   269.7   76.3   134.8  202.9  17.4      962.8    617.7
# 4    1.0   5   181.2  136.1    91.0  214.4   9.8      936.9    624.1
#
#    AirEntrain_Yes
# 0            True
# 1            True
# 2            True
# 3           False
# 4           False

# %% [markdown]
# # 9.4 Using R-like Formulas
#
# In R, regression models are often defined using a compact and intuitive **formula notation** like:

# %%
# Import formula-based API from statsmodels
import statsmodels.formula.api as smf

# Fit the "kitchen sink" model using formula notation
ksf = smf.ols('Strength ~No + Cement + Slag + Water + CoarseAgg + FlyAsh + SP + FineAgg + AirEntrain', data=con)
ksf_res = ksf.fit()

# Summary of the regression model
ksf_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Strength   R-squared:                       0.067
# Model:                            OLS   Adj. R-squared:                 -0.053
# Method:                 Least Squares   F-statistic:                    0.5597
# Date:                Thu, 29 May 2025   Prob (F-statistic):              0.825
# Time:                        13:38:02   Log-Likelihood:                -290.76
# No. Observations:                  80   AIC:                             601.5
# Df Residuals:                      70   BIC:                             625.3
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Simple Explanation of OLS Regression Results
#
# We ran a **linear regression** to predict concrete **Strength** using multiple ingredients (like Cement, Water, etc.). Here’s what the output means in simple terms:
#
# ---
#
# ### What the Numbers Tell Us
#
# | Term | What It Means | Easy Explanation |
# |------|----------------|------------------|
# | **Dependent Variable** | `Strength` | We’re trying to predict this. |
# | **R-squared** | 0.066 | Only **6.6%** of the changes in strength are explained by the model. That’s very low. |
# | **Adjusted R-squared** | -0.039 | Takes into account how many variables we used. Negative value means the model is likely **not useful**. |
# | **F-statistic** | 0.6293 | Tells if the model is overall significant. |
# | **Prob (F-statistic)** | 0.751 | This is very high (> 0.05), so the model is **not statistically significant**. |
# | **Observations** | 80 | You used 80 data points. |
# | **AIC / BIC** | 599.6 / 621.0 | Used to compare models. Lower is better. |
#
# ---
#
# ### Are the Ingredients Important?
#
# | Ingredient | Is it Useful? (P-value) | Meaning |
# |------------|--------------------------|---------|
# | **Cement** | 0.487 | Not useful |
# | **Slag** | 0.439 | Not useful |
# | **Water** | 0.426 | Not useful |
# | **Coarse Aggregate** | 0.520 | Not useful |
# | **Fly Ash** | 0.223 | Not useful |
# | **SP (Superplasticizer)** | 0.833 | Not useful |
# | **Fine Aggregate** | 0.272 | Not useful |
# | **Air Entrainment** | 0.276 | Not useful |
#
# - All these values are **above 0.05**, which means **none of the ingredients are strong predictors** of Strength in this model.
#
# ---
#
# ### Warnings to Watch
#
# - **Durbin-Watson = 2.36**: This is good — it means there’s no big pattern in the errors.
# - **Condition Number = 36700**: This is **too high**. It suggests some ingredients might be **too similar** (called *multicollinearity*), which can confuse the model.
#
# ---
#
# ### What You Can Do Next
#
# - Try **removing or combining variables** that are very similar.
# - Check if some variables are **not needed**.
# - Add more data if possible.
# - You can also try **other models**, like decision trees or random forests, if this one doesn’t work well.
#
# ---
#
# ### Summary
#
# > This model is not good at predicting `Strength`. None of the ingredients are significant on their own. We should improve the model by cleaning data, reducing variables, or trying new methods.

# %% [markdown]
# #9.5: Checking for Collinearity
#
# Multicollinearity occurs when predictor variables are highly correlated. This can inflate standard errors and reduce model interpretability.
#
# We can check for collinearity using:
# 1. **Scatterplot matrix**
# 2. **Correlation matrix**

# %% [markdown]
# ##9.5.1 Scatterplot Matrix

# %%
# Basic scatterplot matrix for all predictors
import seaborn as sns

sns.pairplot(X)

# %% [markdown]
# ### Insight:
# - Histograms on the diagonal
# - Pairwise scatterplots off-diagonal

# %% [markdown]
# ##9.5.2 Restricted Scatterplot Matrix

# %%
# Select fewer variables to improve clarity
subset = ['No', 'Cement', 'Slag', 'FlyAsh', 'Water', 'SP', 'CoarseAgg', 'FineAgg']
sns.pairplot(X[subset])

# %% [markdown]
# ### Observations:
#
# - “FlyAsh”, “Slag”, and “Cement” show patterns suggesting collinearity — potentially a design flaw.

# %% [markdown]
# ##9.5.3 Correlation Matrix

# %% [markdown]
# If the scatterplot matrix remains too hard to read, you can always revert to a simple correlation matrix.

# %%
# Round correlation values for readability
# Compute correlation only for numeric columns
con.select_dtypes(include='number').corr().round(2)
# Out:
#              No  Cement  Slag  FlyAsh  Water    SP  CoarseAgg  FineAgg  \
# No         1.00    0.09 -0.07    0.00   0.06  0.22       0.00    -0.03
# Cement     0.09    1.00 -0.06   -0.09  -0.16  0.12       0.01    -0.14
# Slag      -0.07   -0.06  1.00   -0.19   0.09 -0.22       0.02     0.04
# FlyAsh     0.00   -0.09 -0.19    1.00  -0.13 -0.06      -0.04     0.01
# Water      0.06   -0.16  0.09   -0.13   1.00  0.12      -0.08    -0.30
# SP         0.22    0.12 -0.22   -0.06   0.12  1.00      -0.10     0.01
# CoarseAgg  0.00    0.01  0.02   -0.04  -0.08 -0.10       1.00    -0.19
# FineAgg   -0.03   -0.14  0.04    0.01  -0.30  0.01      -0.19     1.00
# Strength  -0.03    0.06 -0.07   -0.14   0.04  0.01       0.04     0.08
#
#            Strength
# No            -0.03
# Cement         0.06
# Slag          -0.07
# FlyAsh        -0.14
# Water          0.04
# SP             0.01
# CoarseAgg      0.04
# FineAgg        0.08
# Strength       1.00

# %% [markdown]
# ### Interpretation:
# | Variable Pair       | Correlation | Notes                          |
# |---------------------|-------------|--------------------------------|
# | Cement & FlyAsh     | -0.49       | Potential multicollinearity   |
# | Water & CoarseAgg   | -0.60       | Strong inverse relation       |
# | FlyAsh & Strength   | 0.41        | Moderate positive correlation |

# %% [markdown]
# #9.6 Model Refinement

# %% [markdown]
# The kitchen sink model includes all explanatory variables, but it's rarely optimal due to potential issues like multicollinearity or low explanatory power.
#
# ### Objective:
# Refine the model to strike a balance between goodness of fit and model complexity.
#
#
# ###Key Concepts
# - **Adjusted R²** rewards goodness of fit and penalizes complexity.
#
# - **Data mining mode** involves including variables solely based on statistical measures (e.g., p-values, AIC).
#
# - **Heuristic methods** such as AIC, BIC, Mallows Cp help guide variable selection in automated software (like R or SAS).

# %% [markdown]
# ##9.6.1 Manual Stepwise Refinement (Matrix Style)
#
# We start with the full model and remove variables with high p-values iteratively.

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

if 'AirEntrain' in con.columns:
    con['AirEntrain_num'] = con['AirEntrain'].map({'Yes': 1, 'No': 0})

fullX = con[['Cement', 'Slag', 'Water', 'CoarseAgg', 'FlyAsh', 'SP', 'FineAgg', 'AirEntrain_num']]
Y = con['Strength']

X1 = fullX.drop(columns='FineAgg', inplace=False)

X1 = X1.apply(pd.to_numeric, errors='coerce')
Y = pd.to_numeric(Y, errors='coerce')

combined = pd.concat([X1, Y], axis=1).dropna()

X1_clean = combined.drop(columns='Strength')
Y_clean = combined['Strength']

X1_clean = sm.add_constant(X1_clean)

print("X1_clean dtypes:\n", X1_clean.dtypes)
print("Y_clean dtype:", Y_clean.dtypes)
print("X1_clean shape:", X1_clean.shape)
print("Y_clean shape:", Y_clean.shape)

mod1 = sm.OLS(Y_clean, X1_clean)
mod1_res = mod1.fit()

print(mod1_res.summary())
# Out:
# X1_clean dtypes:
#  const             float64
# Cement            float64
# Slag              float64
# Water             float64
# CoarseAgg         float64
# FlyAsh            float64
# SP                float64
# AirEntrain_num      int64
# dtype: object
# Y_clean dtype: float64
# X1_clean shape: (80, 8)
# Y_clean shape: (80,)
#                             OLS Regression Results
# ...
# Dep. Variable:               Strength   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                 -0.042
# Method:                 Least Squares   F-statistic:                    0.5424
# Date:                Thu, 29 May 2025   Prob (F-statistic):              0.799
# Time:                        13:40:33   Log-Likelihood:                -291.48
# No. Observations:                  80   AIC:                             599.0
# Df Residuals:                      72   BIC:                             618.0
# Df Model:                           7
# ...

# %% [markdown]
# ### Data Summary
#
# - **Predictors:** 7 variables + intercept, all numeric
# - **Target (Strength):** numeric
# - **Samples:** 80
#
#
#
# ### Model Fit
#
# - **R-squared:** 0.05 (5% variance explained — very low)
# - **Adj. R-squared:** -0.04 (adjusted for predictors, suggests poor model)
# - **F-statistic p-value:** 0.799 (model not statistically significant)
#
#
#
# ### Coefficients (Effect of each variable)
#
# | Variable       | Coef  | p-value | Interpretation                   |
# |----------------|-------|---------|---------------------------------|
# | const          | 31.38 | 0.17    | Baseline strength, not significant |
# | Cement         | 0.01  | 0.64    | Small effect, not significant     |
# | Slag           | -0.02 | 0.50    | Small negative effect, not significant |
# | Water          | 0.02  | 0.67    | Small effect, not significant     |
# | CoarseAgg      | 0.01  | 0.68    | Small effect, not significant     |
# | FlyAsh         | -0.03 | 0.20    | Small negative effect, not significant |
# | SP             | -0.03 | 0.91    | Almost no effect                  |
# | AirEntrain_num | 2.54  | 0.26    | Positive effect, not significant  |
#
# *None of the variables significantly predict Strength.*

# %% [markdown]
# ##9.6.2 Manual Refinement (Formula Mode)
#
# You can drop variables by editing the formula string:

# %%
# Remove 'FineAgg' in formula mode
mod1f = smf.ols('Strength ~ No + Cement + Slag + Water + CoarseAgg + FlyAsh + SP + AirEntrain', data=con)
mod1f_res = mod1f.fit()
mod1f_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Strength   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                 -0.056
# Method:                 Least Squares   F-statistic:                    0.4765
# Date:                Thu, 29 May 2025   Prob (F-statistic):              0.869
# Time:                        13:46:55   Log-Likelihood:                -291.45
# No. Observations:                  80   AIC:                             600.9
# Df Residuals:                      71   BIC:                             622.3
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# **Formula mode** is useful when dealing with categorical variables or when your dataset is in a DataFrame.

# %% [markdown]
# #9.7 Automated Stepwise Refinement
# Unfortunately, Python libraries don't support automated stepwise regression directly (unlike R or SAS).
#
# **Why?**
#
# - Statisticians prefer domain knowledge over data-driven model selection.
#
# - ML community prefers more flexible, robust methods (e.g., regularization, tree-based models).
#
# **Suggested Approaches:**
#
# 1- Use manual refinement based on theory and data.
#
# 2- Or move beyond OLS to machine learning models.

# %% [markdown]
# #9.8 Regression Diagnostics
#
# We assess whether model assumptions hold using diagnostic plots.

# %% [markdown]
# **Required Imports**

# %%
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# **Residual Histogram + Normal Curve**

# %%
# Deprecation warning for distplot; consider using histplot or displot
sns.histplot(mod1_res.resid, kde=True, stat='density', color='skyblue')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# **Residual Boxplot**

# %%
sns.boxplot(x=mod1_res.resid, showmeans=True)
# Out:
# <Axes: xlabel='None'>

# %% [markdown]
# **Q-Q Plot for Normality**

# %%
sm.qqplot(mod1_res.resid, line='s')
plt.show()

# %% [markdown]
# **Predicted vs. Observed Plot**

# %%
Y_max, Y_min = Y.max(), Y.min()

ax = sns.scatterplot(x=mod1_res.fittedvalues, y=Y)
ax.set(ylim=(Y_min, Y_max), xlim=(Y_min, Y_max))
ax.set_xlabel("Predicted Strength")
ax.set_ylabel("Observed Strength")

# Add 45-degree reference line
plt.plot(np.linspace(Y_min, Y_max, 100), np.linspace(Y_min, Y_max, 100), color='red')
plt.show()

# %% [markdown]
# #9.9 Standardized Regression Coefficients

# %% [markdown]
# **Why standardize?**
#
# - Raw regression coefficients depend on the units of each variable (e.g., kilograms, megapascals).
#
# - Standardized coefficients remove units by converting variables to z-scores (mean=0, std=1).
#
# - This normalization allows you to compare the effect size of variables on the same scale.
#
# - It helps to identify which variables have the strongest impact on the dependent variable relative to others.

# %% [markdown]
# ##9.9.1 Creating standardized input matrices
#
# In Python, we use scipy.stats.zscore() to convert the dependent variable
# 𝑌
#  and explanatory variables
# 𝑋
#  to z-scores:

# %%
from scipy import stats
import pandas as pd
import statsmodels.api as sm

# Standardize Y
Y_norm = pd.Series(stats.zscore(Y), name=Y.name)

# Standardize X, excluding the constant column
X1_no_const = X1.loc[:, X1.columns != "const"]
X1_norm = pd.DataFrame(stats.zscore(X1_no_const), columns=X1_no_const.columns)

# Add the constant column back
X1_norm = sm.add_constant(X1_norm)  # This adds 'const' as the first column

# Now columns will be ['const', <original variables>]
# So no need to reset columns explicitly

# Check means and standard deviations to ensure normalization
check = pd.concat([
    round(X1_norm.mean(axis=0), 5),
    round(X1_norm.std(axis=0, ddof=0), 5)
], axis=1)
check.columns = ["mean", "std dev"]
print(check)
# Out:
#                 mean  std dev
# const            1.0      0.0
# Cement          -0.0      1.0
# Slag             0.0      1.0
# Water            0.0      1.0
# CoarseAgg       -0.0      1.0
# FlyAsh           0.0      1.0
# SP               0.0      1.0
# AirEntrain_num  -0.0      1.0

# %% [markdown]
# **Note on the constant column:**
#
# The constant (intercept) column is all ones, so it has zero variance — its z-score is undefined. We exclude it during standardization and add it back afterward.

# %% [markdown]
# ##9.9.2 Running the standardized regression
#
# Once the inputs are standardized, you run the OLS regression exactly as usual:

# %%
modstd = sm.OLS(Y_norm, X1_norm)
modstd_res = modstd.fit()
print(modstd_res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               Strength   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                 -0.042
# Method:                 Least Squares   F-statistic:                    0.5424
# Date:                Thu, 29 May 2025   Prob (F-statistic):              0.799
# Time:                        14:02:31   Log-Likelihood:                -111.46
# No. Observations:                  80   AIC:                             238.9
# Df Residuals:                      72   BIC:                             258.0
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           4.233e-16      0.115   3.69e-15      1.000      -0.229       0.229
# ...

# %% [markdown]
# - The coefficients here are standardized regression coefficients.
#
# - These indicate how many standard deviations the dependent variable changes per one standard deviation increase in each predictor.
#
# - This allows direct comparison of effect sizes across variables regardless of their original units.

# %% [markdown]
# ##9.9.3 Visualizing with a Tornado Diagram
#
# To better communicate which variables have the biggest impact, a tornado diagram (horizontal bar plot sorted by coefficient magnitude) is ideal:

# %%
import seaborn as sns

coeff = modstd_res.params
# Sort by absolute value descending
coeff = coeff.iloc[(coeff.abs() * -1).argsort()]

sns.barplot(x=coeff.values, y=coeff.index, orient='h')
# Out:
# <Axes: ylabel='None'>

# %% [markdown]
# - This plot visually highlights the most influential variables.
#
# - For the concrete strength model, Cement and FlyAsh typically show the largest standardized coefficients — making them the strongest predictors.

# %% [markdown]
# #9.10 Stepwise Refinement: An Aside
#
# Stepwise regression is a method of iteratively building a regression model by adding or removing predictors based on statistical metrics. While R provides a built-in step() function, Python lacks a direct equivalent in common libraries. However, the mlxtend library provides a suitable alternative using Sequential Feature Selector (SFS).

# %% [markdown]
# ##9.10.1 Create a sklearn Kitchen Sink Model
#
# We'll use sklearn's LinearRegression, which differs from statsmodels:
#
# - No need to add a constant column.
#
# - No regression summary table—must inspect manually.

# %%
# Make a copy of fullX
X2 = fullX.copy()

# Drop 'const' column only if it exists
if 'const' in X2.columns:
    X2.drop('const', axis=1, inplace=True)

# Display the first few rows
X2.head(3)
# Out:
#    Cement  Slag  Water  CoarseAgg  FlyAsh    SP  FineAgg AirEntrain_num
# 0   224.9   4.7  126.7      939.6    96.3   6.5    633.8              1
# 1   340.1  95.5  189.1      907.2    12.6  18.5    655.7              1
# 2   296.4  47.2  190.3      861.9    24.2  12.6    635.4              1

# %%
from sklearn.linear_model import LinearRegression
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs

# Fit a full model using sklearn
mod = LinearRegression()
mod.fit(X2, Y)
# Out:
# LinearRegression()

# %%
# View coefficients manually
coef = pd.concat([pd.Series(X2.columns), pd.Series(mod.coef_)], axis=1)
coef.columns = ["variable", "coefficient"]
coef
# Out:
#          variable  coefficient
# 0          Cement     0.015204
# 1            Slag    -0.020229
# 2           Water     0.030549
# 3       CoarseAgg     0.014039
# 4          FlyAsh    -0.031253
# 5              SP    -0.054049
# 6         FineAgg     0.026714
# 7  AirEntrain_num     2.467679

# %% [markdown]
# ##9.10.2 Running the Stepwise Refinement Algorithm
#
# We now use mlxtend's Sequential Feature Selector to apply backward stepwise selection.

# %%
sfs = SFS(mod,
          k_features='best',
          forward=False,     # Backward stepwise
          floating=False,
          scoring='r2',      # Use R-squared as scoring metric
          cv=30)             # 30-fold cross-validation

sfs = sfs.fit(X2, Y)

# %% [markdown]
# ##9.10.3 Viewing the Iterations
#
# The output of sfs can be converted into a DataFrame. Each row shows a model with a specific number of features.

# %%
sfs_results = pd.DataFrame.from_dict(sfs.get_metric_dict(confidence_interval=0.95)).T
sfs_results.sort_values(by='avg_score', ascending=False)
# Out:
#                 feature_idx  \
# 1                      (7,)
# 2                    (3, 7)
# 3                 (1, 3, 7)
# 4              (1, 3, 5, 7)
# 5           (0, 1, 3, 5, 7)
# 6        (0, 1, 2, 3, 5, 7)
# 7     (0, 1, 2, 3, 4, 5, 7)
# 8  (0, 1, 2, 3, 4, 5, 6, 7)
#
#                                            cv_scores avg_score  \
# 1  [-0.005229412074374773, -0.16187206219117067, ... -2.285988
# 2  [-0.03625158766771941, -0.3108075576615368, -0... -2.319425
# 3  [-0.15898672207323727, -0.2962806922521106, -0... -2.399205
# 4  [-0.2892131755623084, -0.2944903426262919, -0.... -2.556183
# 5  [-0.27107535431242025, -0.3032222382427192, -0... -2.718401
# 6  [-0.24341431182558337, -0.28604953735529204, -... -2.901043
# 7  [-0.1664495834977664, -0.0516553892095335, 0.0... -3.302863
# 8  [-0.07449517692244978, 0.10063943750642002, 0.... -3.606008
#
#                                        feature_names  ci_bound   std_dev  \
# ...

# %% [markdown]
# ##9.10.4 Picking the Best Model Visually
#
# MLxtend includes a plot function to help visualize model performance across different subsets.

# %%
plot_sfs(sfs.get_metric_dict(), kind='std_err')
plt.grid()
plt.show()

# %% [markdown]
# ##9.10.5 Viewing the Best Model
#
# We can extract the features from the best-performing model (8 features).

# %%
sfs.subsets_[8].get('feature_names')
# Out:
# ('Cement',
#  'Slag',
#  'Water',
#  'CoarseAgg',
#  'FlyAsh',
#  'SP',
#  'FineAgg',
#  'AirEntrain_num')

# %% [markdown]
# Note: This model excluded “Water”, while our manual method excluded “FineAgg”. Even R’s step() drops "FineAgg". This inconsistency demonstrates why stepwise selection is not always robust and may not be favored in modern ML pipelines. Still, it's useful for exploratory and educational purposes.

# %% [markdown]
# ---
